# %%
set a colour program

# %%
colours={"purple","white","brown","indigo","yellow","black","marron","green","navyblue","orange"}

# %%
colours
# Out:
# {'black',
#  'brown',
#  'green',
#  'indigo',
#  'marron',
#  'navyblue',
#  'orange',
#  'purple',
#  'white',
#  'yellow'}
